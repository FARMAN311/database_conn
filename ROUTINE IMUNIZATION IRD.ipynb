# %%
import pandas as pd
file_1 = pd.read_excel('file_1.xlsx', sheet_name="S.I.T.E Town", skiprows=3, header=1)
file_1.head()
# Out:
#        IDENTIFIER  ENROLLMENTEPINUMBER  CHILDNAME     FATHERNAME   BIRTHDATE  \
# 0  20200001732038           20210050.0   NO NAME         Saeed    03-02-2021
# 1  20200001732037           20210051.0   NO NAME    Fareed khan   03-02-2021
# 2  20200001772043           20211991.0  Jackson            alex   04-02-2021
# 3  20200001731240           20210031.0   NO NAME   Sarwar Khan    09-02-2021
# 4  20200001731244           20210034.0    Ajwah     Sajjad Ali    02-02-2021
#
#    PRIMARYCONTACT                                            ADDRESS  \
# 0             NaN                                 metroville block 3
# 1    3.462614e+09                          L.s o1 metroville block 5
# 2    3.172524e+09                         new golimar zimmedar hotel
# 3             NaN               786/Street#,10 Laasi Para Meera Naka
# 4    3.442780e+09  Tenants KESC969/Ghousia Mohallah Frontier Colo...
#
#                 UC TOWN/TALUKA         DISTRICT  TOTALDEFAULTED  \
# ...

# %%
file_2 = pd.read_excel('file_2.xlsx', sheet_name="Keamari Town",skiprows=3, header=1)
file_2.head()
# Out:
#        IDENTIFIER  ENROLLMENTEPINUMBER       CHILDNAME      FATHERNAME  \
# 0  20200001465319           20210421.0        Shanzey          Tayyab
# 1  20202000094283           20210320.0         ayesha   Adil Shahzad
# 2  20202000090050           20210337.0          mehak          mazhar
# 3  20202000090051           20210338.0   Urooj fatima        Sher ali
# 4  20190001630155           20210230.0  Muhammad anas     Najmul alim
#
#     BIRTHDATE  PRIMARYCONTACT                   ADDRESS           UC  \
# 0  01-02-2021             NaN                 anre pnad    Gabopat-8
# 1  06-02-2021    3.128760e+09           mushraf colony     Maripur-6
# 2  04-02-2021    3.452596e+09                  shershah  Sher Shah-7
# 3  04-02-2021    3.153103e+09             sindh makilay    Gabopat-8
# 4  01-02-2021             NaN  street 30 muhammadi road  Sher Shah-7
#
#   TOWN/TALUKA         DISTRICT  TOTALDEFAULTED DEFAULTEDVACCINE  \
# ...

# %%
file_3 = pd.read_excel("file_3.xlsx", sheet_name='Baldia Town', skiprows=3, header=1)
file_3.head()
#file_3.rename(columns={'IDENTIFIER':'new_name'}, inplace=True)
#file_3
# Out:
#        IDENTIFIER  ENROLLMENTEPINUMBER CHILDNAME FATHERNAME   BIRTHDATE  \
# 0  20210000100980           20210343.0  NO NAME    Shahid    01-02-2021
# 1  20210000110988           20210319.0    hadiu       Aziz   01-02-2021
# 2  20200001675483           20210015.0      Boy      Waqer   01-02-2021
# 3  20210000104948           20215865.0   faizas    Dilawar   02-02-2021
# 4  20200000740405           20210210.0   khula     Mehboob   04-02-2021
#
#    PRIMARYCONTACT ADDRESS                     UC TOWN/TALUKA         DISTRICT  \
# 0             NaN     NaN      Gulshan-e-Ghazi-1      Baldia  Kemari District
# 1    3.142578e+09     NaN  Muslim Mujahid Colony      Baldia  Kemari District
# 2             NaN  Baldia      Gulshan-e-Ghazi-1      Baldia  Kemari District
# 3             NaN  Baldia          Rasheedabad-8      Baldia  Kemari District
# 4    3.181258e+09     NaN         Ittehad Town-2      Baldia  Kemari District
#
# ...

# %%
if((file_1.columns.any() == file_2.columns.any()) and (file_1.columns.any() == file_3.columns.any())):
    print("3 tables columns are same")
else:
        print("not same")
# Out:
# 3 tables columns are same

# %%
file_123= pd.concat([file_1,file_2,file_3])
file_123
# Out:
#            IDENTIFIER  ENROLLMENTEPINUMBER       CHILDNAME     FATHERNAME  \
# 0      20200001732038           20210050.0        NO NAME         Saeed
# 1      20200001732037           20210051.0        NO NAME    Fareed khan
# 2      20200001772043           20211991.0       Jackson            alex
# 3      20200001731240           20210031.0        NO NAME   Sarwar Khan
# 4      20200001731244           20210034.0         Ajwah     Sajjad Ali
# ...               ...                  ...             ...            ...
# 14815  20229002408284           20220000.0        Muraid     Shoukat ali
# 14816  20229002408214           20220000.0     Yasir khan   Ashifaq khan
# 14817  20229002408211           20220000.0         Rizwan         Ramzan
# 14818  20230000000339           20230001.0  Mustafa kamal     Haseeb gul
# 14819  20230000023386           20230003.0          Nadia          Anwer
#
#         BIRTHDATE  PRIMARYCONTACT  \
# 0      03-02-2021             NaN
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31714 entries, 0 to 14819
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDENTIFIER                 31714 non-null  int64
#  1   ENROLLMENTEPINUMBER        29646 non-null  float64
#  2   CHILDNAME                  31714 non-null  object
#  3   FATHERNAME                 31714 non-null  object
#  4   BIRTHDATE                  31714 non-null  object
#  5   PRIMARYCONTACT             14907 non-null  float64
#  6   ADDRESS                    29719 non-null  object
#  7   UC                         31714 non-null  object
#  8   TOWN/TALUKA                31714 non-null  object
#  9   DISTRICT                   31714 non-null  object
#  10  TOTALDEFAULTED             31714 non-null  int64
#  11  DEFAULTEDVACCINE           31714 non-null  object
#  12  DEFAULTEDVACCINEDUEDATE    31714 non-null  object
# ...

# %%
a=file_123['BIRTHDATE'] = file_123['BIRTHDATE'].astype(str)
a.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 31714 entries, 0 to 14819
# Series name: BIRTHDATE
# Non-Null Count  Dtype
# --------------  -----
# 31714 non-null  object
# dtypes: object(1)
# memory usage: 495.5+ KB

# %%
#file_123['BIRTHDATE'] = pd.to_datetime([file_123['BIRTHDATE']])
file_123[['day','month','year']] = file_123['BIRTHDATE'].str.split("-", expand=True)
file_123
# Out:
#            IDENTIFIER  ENROLLMENTEPINUMBER       CHILDNAME     FATHERNAME  \
# 0      20200001732038           20210050.0        NO NAME         Saeed
# 1      20200001732037           20210051.0        NO NAME    Fareed khan
# 2      20200001772043           20211991.0       Jackson            alex
# 3      20200001731240           20210031.0        NO NAME   Sarwar Khan
# 4      20200001731244           20210034.0         Ajwah     Sajjad Ali
# ...               ...                  ...             ...            ...
# 14815  20229002408284           20220000.0        Muraid     Shoukat ali
# 14816  20229002408214           20220000.0     Yasir khan   Ashifaq khan
# 14817  20229002408211           20220000.0         Rizwan         Ramzan
# 14818  20230000000339           20230001.0  Mustafa kamal     Haseeb gul
# 14819  20230000023386           20230003.0          Nadia          Anwer
#
#         BIRTHDATE  PRIMARYCONTACT  \
# 0      03-02-2021             NaN
# ...

# %%
file_123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31714 entries, 0 to 14819
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDENTIFIER                 31714 non-null  int64
#  1   ENROLLMENTEPINUMBER        29646 non-null  float64
#  2   CHILDNAME                  31714 non-null  object
#  3   FATHERNAME                 31714 non-null  object
#  4   BIRTHDATE                  31714 non-null  object
#  5   PRIMARYCONTACT             14907 non-null  float64
#  6   ADDRESS                    29719 non-null  object
#  7   UC                         31714 non-null  object
#  8   TOWN/TALUKA                31714 non-null  object
#  9   DISTRICT                   31714 non-null  object
#  10  TOTALDEFAULTED             31714 non-null  int64
#  11  DEFAULTEDVACCINE           31714 non-null  object
#  12  DEFAULTEDVACCINEDUEDATE    31714 non-null  object
# ...

# %%
file_123['day'] = file_123['day'].astype(int)
file_123['month'] = file_123['month'].astype(int)
file_123['year'] = file_123['year'].astype(int)
file_123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31714 entries, 0 to 14819
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDENTIFIER                 31714 non-null  int64
#  1   ENROLLMENTEPINUMBER        29646 non-null  float64
#  2   CHILDNAME                  31714 non-null  object
#  3   FATHERNAME                 31714 non-null  object
#  4   BIRTHDATE                  31714 non-null  object
#  5   PRIMARYCONTACT             14907 non-null  float64
#  6   ADDRESS                    29719 non-null  object
#  7   UC                         31714 non-null  object
#  8   TOWN/TALUKA                31714 non-null  object
#  9   DISTRICT                   31714 non-null  object
#  10  TOTALDEFAULTED             31714 non-null  int64
#  11  DEFAULTEDVACCINE           31714 non-null  object
#  12  DEFAULTEDVACCINEDUEDATE    31714 non-null  object
# ...

# %%
file_123['day'].max()
# Out:
# 31

# %%
#BIRTHDATE = pd.concat([file_123['day'],file_123['month'],file_123['year']], axis=1)
#BIRTHDATE
file_123['BIRTHDATE'] = pd.to_datetime(file_123[['year', 'month', 'day']])
file_123
# Out:
#            IDENTIFIER  ENROLLMENTEPINUMBER       CHILDNAME     FATHERNAME  \
# 0      20200001732038           20210050.0        NO NAME         Saeed
# 1      20200001732037           20210051.0        NO NAME    Fareed khan
# 2      20200001772043           20211991.0       Jackson            alex
# 3      20200001731240           20210031.0        NO NAME   Sarwar Khan
# 4      20200001731244           20210034.0         Ajwah     Sajjad Ali
# ...               ...                  ...             ...            ...
# 14815  20229002408284           20220000.0        Muraid     Shoukat ali
# 14816  20229002408214           20220000.0     Yasir khan   Ashifaq khan
# 14817  20229002408211           20220000.0         Rizwan         Ramzan
# 14818  20230000000339           20230001.0  Mustafa kamal     Haseeb gul
# 14819  20230000023386           20230003.0          Nadia          Anwer
#
#        BIRTHDATE  PRIMARYCONTACT  \
# 0     2021-02-03             NaN
# ...

# %%
file_123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31714 entries, 0 to 14819
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDENTIFIER                 31714 non-null  int64
#  1   ENROLLMENTEPINUMBER        29646 non-null  float64
#  2   CHILDNAME                  31714 non-null  object
#  3   FATHERNAME                 31714 non-null  object
#  4   BIRTHDATE                  31714 non-null  datetime64[ns]
#  5   PRIMARYCONTACT             14907 non-null  float64
#  6   ADDRESS                    29719 non-null  object
#  7   UC                         31714 non-null  object
#  8   TOWN/TALUKA                31714 non-null  object
#  9   DISTRICT                   31714 non-null  object
#  10  TOTALDEFAULTED             31714 non-null  int64
#  11  DEFAULTEDVACCINE           31714 non-null  object
#  12  DEFAULTEDVACCINEDUEDATE    31714 non-null  object
# ...

# %%
file_uni = file_123.drop_duplicates(subset='ENROLLMENTEPINUMBER', keep='first', inplace=False)
file_uni.head(3)
# Out:
#        IDENTIFIER  ENROLLMENTEPINUMBER  CHILDNAME    FATHERNAME  BIRTHDATE  \
# 0  20200001732038           20210050.0   NO NAME        Saeed   2021-02-03
# 1  20200001732037           20210051.0   NO NAME   Fareed khan  2021-02-03
# 2  20200001772043           20211991.0  Jackson           alex  2021-02-04
#
#    PRIMARYCONTACT                     ADDRESS             UC TOWN/TALUKA  \
# 0             NaN          metroville block 3     Metrovil-4   S.I.T.E-1
# 1    3.462614e+09   L.s o1 metroville block 5     Metrovil-4   S.I.T.E-1
# 2    3.172524e+09  new golimar zimmedar hotel  Old Golimar-2   S.I.T.E-1
#
#           DISTRICT  ...  DEFAULTEDDATE     STATUS VACCINATIONDATE  \
# 0  Kemari District  ...     02-01-2023  DEFAULTED             NaN
# 1  Kemari District  ...     09-08-2022  DEFAULTED             NaN
# 2  Kemari District  ...     04-06-2022  DEFAULTED             NaN
#
#   DEFAULTEDVACCINEEVENTTYPE ENROLLMENTCENTERNAME  ENROLLMENTVACCINATORNAME  \
# ...

# %%
col_district = file_123['DISTRICT'].value_counts()
col_district
# Out:
# Kemari District    31714
# Name: DISTRICT, dtype: int64

# %%
file_123["IDENTIFIER"].duplicated().count()
# Out:
# 31714

# %%
file_123['TOWN/TALUKA'].nunique()
# Out:
# 3

# %%
file_final =pd.pivot_table(file_123, index=['TOWN/TALUKA','UC'] ,columns=['DISTRICT'],  values='CHILDNAME',aggfunc='count',margins=True)
file_final
# Out:
# DISTRICT                           Kemari District    All
# TOWN/TALUKA UC
# Baldia      Gulshan-e-Ghazi-1                 3824   3824
#             Islam Nagar-3                     2820   2820
#             Ittehad Town-2                    4068   4068
#             Muhajir Camp-7                     492    492
#             Muslim Mujahid Colony              863    863
#             Nai Abadi-4                        577    577
#             Rasheedabad-8                      794    794
#             Saeedabad-5                       1382   1382
# Kemari       Bhutta Village-1                 1648   1648
#              Gabopat-8                        2022   2022
#             Baba Bhit-4                        385    385
#             Kemari-3                          1810   1810
#             Machar Colony-5                   2673   2673
#             Maripur-6                         1337   1337
#             Sher Shah-7                       1854   1854
# ...

# %%
file_final.to_csv('pivot.csv')

# %%
file_123.to_excel('compile.xlsx')

# %%
file_uni.to_excel('unique.xlsx')
